# %% [markdown]
# # Week 2
# #### Exercise
# Use and experience methods from previous lessons with given data. Try to search for other pandas methods to analyze the data such as groupby() and read_csv().

# %%
import pandas as pd
import numpy as np

# %%
recovered_dataset_url = r"data\time_series_covid19_recovered_global.csv"
deaths_dataset_url =r"data\time_series_covid19_deaths_global.csv"
recovered = pd.read_csv(recovered_dataset_url)
deaths = pd.read_csv(deaths_dataset_url)

# %%
#base_url=r"data\\time_series_covid19_confirmed_global.csv"
base_url=r"data\time_series_covid19_confirmed_global.csv"
infected  = pd.read_csv(base_url)
print(infected )
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
infected.size
# Out:
# 39900

# %%
infected.shape
# Out:
# (266, 150)

# %%
infected[["Country/Region","Lat"]]
# Out:
#             Country/Region        Lat
# 0              Afghanistan  33.000000
# 1                  Albania  41.153300
# 2                  Algeria  28.033900
# 3                  Andorra  42.506300
# 4                   Angola -11.202700
# ..                     ...        ...
# 261  Sao Tome and Principe   0.186360
# 262                  Yemen  15.552727
# 263                Comoros -11.645500
# 264             Tajikistan  38.861034
# 265                Lesotho -29.609988
#
# [266 rows x 2 columns]

# %%
infected[["Lat"]]>0
# Out:
#        Lat
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# ..     ...
# 261   True
# 262   True
# 263  False
# 264   True
# 265  False
#
# [266 rows x 1 columns]

# %%
infected.loc[data['Lat']>0]
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 5              NaN    Antigua and Barbuda  17.060800 -61.796400        0
# ..             ...                    ...        ...        ...      ...
# 259            NaN            South Sudan   6.877000  31.307000        0
# 260            NaN         Western Sahara  24.215500 -12.885800        0
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
turkey_data = infected[infected['Country/Region'] == 'Turkey']
turkey_data
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 213            NaN         Turkey  38.9637  35.2433        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# 213        0        0        0        0  ...  169218  170132  171121  172114
#
#      6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 213   173036   174023   175218   176677   178239   179831
#
# [1 rows x 150 columns]

# %%
mean_value = infected['6/6/20'].mean()
mean_value
# Out:
# 25949.812030075187

# %%
date_range = infected.loc[:, '6/6/20':'6/15/20']
date_range
# Out:
#      6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  6/11/20  6/12/20  6/13/20  \
# 0     19551   20342   20917   21459    22142    22890    23546    24102
# 1      1232    1246    1263    1299     1341     1385     1416     1464
# 2     10050   10154   10265   10382    10484    10589    10698    10810
# 3       852     852     852     852      852      852      853      853
# 4        88      91      92      96      113      118      130      138
# ..      ...     ...     ...     ...      ...      ...      ...      ...
# 261     499     513     513     514      611      632      639      659
# 262     482     484     496     524      560      591      632      705
# 263     141     141     141     141      162      162      163      176
# 264    4453    4529    4609    4690     4763     4834     4902     4971
# 265       4       4       4       4        4        4        4        4
#
#      6/14/20  6/15/20
# 0      24766    25527
# 1       1521     1590
# 2      10919    11031
# ...

# %%
infected['Total Cases'] = infected.loc[:, '1/22/20':'6/15/20'].sum(axis=1)
infected
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/7/20  6/8/20  6/9/20  \
# ...

# %%
max_cases_country = infected.loc[infected['Total Cases'].idxmax(), 'Country/Region']
max_cases_country
# Out:
# 'US'

# %%
min_cases_country = infected.loc[infected['Total Cases'].idxmin(), 'Country/Region']
min_cases_country
# Out:
# 'Canada'

# %%
infected[infected['Country/Region'] == 'China']
# Out:
#     Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 49           Anhui          China  31.8257  117.2264        1        9
# 50         Beijing          China  40.1824  116.4142       14       22
# 51       Chongqing          China  30.0572  107.8740        6        9
# 52          Fujian          China  26.0789  117.9874        1        5
# 53           Gansu          China  37.8099  101.0583        0        2
# 54       Guangdong          China  23.3417  113.4244       26       32
# 55         Guangxi          China  23.8298  108.7881        2        5
# 56         Guizhou          China  26.8154  106.8748        1        3
# 57          Hainan          China  19.1959  109.7453        4        5
# 58           Hebei          China  39.5490  116.1306        1        1
# 59    Heilongjiang          China  47.8620  127.7615        0        2
# 60           Henan          China  33.8820  113.6140        5        5
# ...

# %%
df_infected = infected.groupby('Country/Region').sum()
df_infected.head()
# Out:
# C:\Users\nesli\AppData\Local\Temp\ipykernel_6296\3060512869.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_infected = infected.groupby('Country/Region').sum()
#                     Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan     33.0000  65.0000        0        0        0        0        0
# Albania         41.1533  20.1683        0        0        0        0        0
# Algeria         28.0339   1.6596        0        0        0        0        0
# Andorra         42.5063   1.5218        0        0        0        0        0
# Angola         -11.2027  17.8739        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  ...  6/6/20  6/7/20  6/8/20  \
# Country/Region                             ...
# ...

# %%
df_recovered = recovered.groupby('Country/Region').sum()
df_deaths = deaths.groupby('Country/Region').sum()
df_infected.loc['China']
df_infected.loc['China'].to_frame()
# Out:
# C:\Users\nesli\AppData\Local\Temp\ipykernel_6296\2292407587.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_recovered = recovered.groupby('Country/Region').sum()
# C:\Users\nesli\AppData\Local\Temp\ipykernel_6296\2292407587.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_deaths = deaths.groupby('Country/Region').sum()
#               China
# Lat       1083.3367
# Long      3684.4197
# 1/22/20    548.0000
# 1/23/20    643.0000
# 1/24/20    920.0000
# ...             ...
# 6/11/20  84216.0000
# 6/12/20  84228.0000
# 6/13/20  84286.0000
# 6/14/20  84335.0000
# 6/15/20  84378.0000
#
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)

# %%
df_infected.loc['China'][2:].plot()
df_deaths.loc['China'][2:].plot()
df_recovered.loc['China'][2:].plot()
plt.show()
